# %% [markdown]
# <a href="https://colab.research.google.com/github/saradhavaranasi15/Notification-service/blob/main/tupleunit3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t=(1,1,2,2,3,44.6,678.9,'hello')
print(t)
print(type(t))
# Out:
# (1, 1, 2, 2, 3, 44.6, 678.9, 'hello')
# <class 'tuple'>

# %%
t1=()
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t1=(1,5,7,8)
t2=(9,6,10)
print(t1+t2)
# Out:
# (1, 5, 7, 8, 9, 6, 10)

# %%
t1=(11,33,44)
for i in t1:
  print(i)
# Out:
# 11
# 33
# 44

# %%
t2=(2,5,7,8)
print(t2*4)
# Out:
# (2, 5, 7, 8, 2, 5, 7, 8, 2, 5, 7, 8, 2, 5, 7, 8)

# %%
t1=[11,33,44]
t1[2]="python"
print(t1)
# Out:
# [11, 33, 'python']

# %%
t1=(11,'hello',33)

print(t1.count("hello"))
# Out:
# 1

# %%
#write a program to create tuples (name,age,address,college) for at least two numbers and concatenate the tuples and print the concatenated tuples
t1=('sita',18,'hyd','srm')
t2=('sai',19,'vizag','vit')
print(t1+t2)
# Out:
# ('sita', 18, 'hyd', 'srm', 'sai', 19, 'vizag', 'vit')

# %%
t1=(10,20,30,40,50)
print(t1[4])
print(t1[1::2])
print(t1[::-1])
print(t1[0::2])
# Out:
# 50
# (20, 40)
# (50, 40, 30, 20, 10)
# (10, 30, 50)

# %%
t1=tuple(map(int,input().split()))
print(t1)
# Out:
# 9 8 7 5 3 5 66
# (9, 8, 7, 5, 3, 5, 66)

# %%
#write the program to count no.of vowels in the list
s=str(input("enter a string:"))
s1=s.lower()
vowel_count=s1.count("a")+s1.count("e")+s1.count("i")+s1.count("o")+s1.count("u")
print("the vowel count:",vowel_count)
# Out:
# enter a string:hello world
# the vowel count: 3

# %%
t1=(input("enter a number:"))
if t1==t1[::-1]:
 print(t1[::-1])
# Out:
# enter a number:234

# %%
s={1,2,3,4,"hello"}
print(s)
print(type(s))
# Out:
# {1, 2, 3, 4, 'hello'}
# <class 'set'>

# %%
#set operations
A={1,2,3,4}
B={6,7,8,9}
print(A|B)
print(A&B)
print(A-B)
print(A^B)
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9}
# set()
# {1, 2, 3, 4}
# {1, 2, 3, 4, 6, 7, 8, 9}

# %%
#set methods
s={1,2,3,4}
s.add(23)
print(s)
s.remove(23)
print(s)
s.update([44,66,77])
print(s)
print(A.issuperset(B))
print(B.issubset(A))
a=s.pop()
print(s)
s.discard(2)
print(s)
s.clear()
print(s)
# Out:
# {1, 2, 3, 4, 23}
# {1, 2, 3, 4}
# {1, 2, 3, 4, 66, 44, 77}
# False
# False
# {2, 3, 4, 66, 44, 77}
# {3, 4, 66, 44, 77}
# set()
